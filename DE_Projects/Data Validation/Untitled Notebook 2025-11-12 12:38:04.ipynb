# %%
# File path in Unity Catalog Volume
file_path = "/Volumes/workspace/project/customer/customers.csv"

# Read the CSV file as a Spark DataFrame
df = spark.read.option("header", True).option("inferSchema", True).csv(file_path)

# Display the DataFrame
display(df)

# %%
files = dbutils.fs.ls('/Volumes/qc_validation/raw_files/data/')

# %%
files

# %%
[FileInfo(path='dbfs:/Volumes/qc_validation/raw_files/data/customers.csv', name='customers.csv', size=1507, modificationTime=1763306792000),
 FileInfo(path='dbfs:/Volumes/qc_validation/raw_files/data/customers1 copy.csv', name='customers1 copy.csv', size=86, modificationTime=1763307279000),
 FileInfo(path='dbfs:/Volumes/qc_validation/raw_files/data/customers1.csv', name='customers1.csv', size=313, modificationTime=1763306915000),
 FileInfo(path='dbfs:/Volumes/qc_validation/raw_files/data/products copy1.csv', name='products copy1.csv', size=88, modificationTime=1763277536000),
 FileInfo(path='dbfs:/Volumes/qc_validation/raw_files/data/products.csv', name='products.csv', size=314, modificationTime=1763105870000),
 FileInfo(path='dbfs:/Volumes/qc_validation/raw_files/data/stores copy.csv', name='stores copy.csv', size=84, modificationTime=1763277536000),
 FileInfo(path='dbfs:/Volumes/qc_validation/raw_files/data/stores.csv', name='stores.csv', size=181, modificationTime=1763105869000),
 FileInfo(path='dbfs:/Volumes/qc_validation/raw_files/data/transactions_20251112.csv', name='transactions_20251112.csv', size=48842, modificationTime=1763129912000),
 FileInfo(path='dbfs:/Volumes/qc_validation/raw_files/data/transactions_20251113.csv', name='transactions_20251113.csv', size=456, modificationTime=1763277536000)]

# %%
# %sql
select * from qc_validation.silver.silver_customers

# %%
# %sql
select * from qc_validation.silver.silver_customers

# %%
# %sql
select * from qc_validation.bronze.bronze_customers

# %%
# %sql
select * from qc_validation.silver.silver_products;

# %%
# %sql
select * from qc_validation.bronze.bronze_products;

# %%
from delta.tables import DeltaTable
DeltaTable.forName(spark, 'qc_validation.silver.silver_products')

# %%
# %sql
select * from qc_validation.bronze.bronze_products where  _record_ingestion_ts> (select max (_record_ingestion_ts) from qc_validation.silver.silver_products)

# %%
# %sql
select * from qc_validation.bronze.bronze_products

# %%
# %sql
select * from qc_validation.silver.silver_products

# %%
# %sql
select * from qc_validation.silver.silver_stores;

# %%
# %sql
select * from qc_validation.bronze.bronze_stores;

# %%
# %sql
select * from qc_validation.silver.silver_stores;

# %%
# %sql
select transaction_id,count(*) from qc_validation.bronze.bronze_transactions where  _record_ingestion_ts> (select max (_record_ingestion_ts) from qc_validation.silver.silver_transactions) group by transaction_id

# %%
# %sql
select * from qc_validation.bronze.bronze_transactions where  _record_ingestion_ts> (select max (_record_ingestion_ts) from qc_validation.silver.silver_transactions)

# %%
# %sql
select * from qc_validation.bronze.bronze_customers where  _record_ingestion_ts> (select max (_record_ingestion_ts) from qc_validation.silver.silver_customers)

# %%
# %sql
select * from qc_validation.bronze.bronze_customers

# %%
# %sql
select max (_record_ingestion_ts) from qc_validation.silver.silver_customers

# %%
# %sql
select * from qc_validation.silver.silver_customers

# %%
# %sql
select * from qc_validation.silver.silver_transactions

# %%
# %sql
update qc_validation.bronze.bronze_transactions set sku='SKU-400' where transaction_id='T20251112_20022'
